# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("ParisHousing.csv")

# %%
data.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   squareMeters       10000 non-null  int64
#  1   numberOfRooms      10000 non-null  int64
#  2   hasYard            10000 non-null  int64
#  3   hasPool            10000 non-null  int64
#  4   floors             10000 non-null  int64
#  5   cityCode           10000 non-null  int64
#  6   cityPartRange      10000 non-null  int64
#  7   numPrevOwners      10000 non-null  int64
#  8   made               10000 non-null  int64
#  9   isNewBuilt         10000 non-null  int64
#  10  hasStormProtector  10000 non-null  int64
#  11  basement           10000 non-null  int64
#  12  attic              10000 non-null  int64
#  13  garage             10000 non-null  int64
#  14  hasStorageRoom     10000 non-null  int64
#  15  hasGuestRoom       10000 non-null  int64
# ...

# %%
data.describe().T
# Out:
#                      count          mean           std      min         25%  \
# squareMeters       10000.0  4.987013e+04  2.877438e+04     89.0    25098.50
# numberOfRooms      10000.0  5.035840e+01  2.881670e+01      1.0       25.00
# hasYard            10000.0  5.087000e-01  4.999493e-01      0.0        0.00
# hasPool            10000.0  4.968000e-01  5.000148e-01      0.0        0.00
# floors             10000.0  5.027630e+01  2.888917e+01      1.0       25.00
# cityCode           10000.0  5.022549e+04  2.900668e+04      3.0    24693.75
# cityPartRange      10000.0  5.510100e+00  2.872024e+00      1.0        3.00
# numPrevOwners      10000.0  5.521700e+00  2.856667e+00      1.0        3.00
# made               10000.0  2.005488e+03  9.308090e+00   1990.0     1997.00
# isNewBuilt         10000.0  4.991000e-01  5.000242e-01      0.0        0.00
# hasStormProtector  10000.0  4.999000e-01  5.000250e-01      0.0        0.00
# ...

# %%
plt.figure(figsize=(18,10))
sns.heatmap(data.corr(),annot=True,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
sns.lineplot("made","price",data=data)
# Out:
# <AxesSubplot:xlabel='made', ylabel='price'>

# %%
sns.countplot(data["hasYard"],hue=data["hasPool"])
# Out:
# <AxesSubplot:xlabel='hasYard', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x=data["hasPool"],y=data["price"],hue=data["cityPartRange"])
# Out:
# <AxesSubplot:xlabel='hasPool', ylabel='price'>

# %%
plt.figure(figsize=(12,10))
sns.violinplot(data=data,x=data["cityPartRange"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='cityPartRange', ylabel='price'>

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=data,x=data["cityPartRange"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='cityPartRange', ylabel='price'>

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=data,x=data["cityPartRange"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='cityPartRange', ylabel='price'>

# %%
sns.scatterplot(data=data,x=data["hasStormProtector"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='hasStormProtector', ylabel='price'>

# %%
sns.kdeplot(data["price"],hue=data["hasStormProtector"],multiple="stack",palette="viridis")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(data["made"],hue=data["hasStormProtector"])
# Out:
# <AxesSubplot:xlabel='made', ylabel='count'>

# %%
sns.boxplot(x="hasYard",y="made",hue="hasPool",data=data,palette="mako")
# Out:
# <AxesSubplot:xlabel='hasYard', ylabel='made'>

# %%
made_price = data[["made","price"]]

# %%
made_price = data.groupby(by="made").mean().reset_index()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x=made_price["made"],y=made_price["price"])
plt.xlabel("Yapım Yılı")
plt.ylabel("Fiyat")
plt.title("Yıllara Göre Ortalama Ev Fiyatları")
# Out:
# Text(0.5, 1.0, 'Yıllara Göre Ortalama Ev Fiyatları')

# %%
data.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %%
data["bas_at_gar"] = data["basement"] + data["attic"] + data["garage"]

# %%
data.head(10)
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
# 5         39223             36        0        1      17     39489
# 6         58682             10        1        1      99      6450
# 7         86929            100        1        0      11     98155
# 8         51522              3        0        0      61      9047
# 9         39686             42        0        0      15     71019
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# ...

# %%
sns.jointplot(x="basement",y="price",data=data,color="red")

# %%
sns.jointplot(x="attic",y="price",data=data,color="green")

# %%
sns.jointplot(x="garage",y="price",data=data,color="blue")

# %%
plt.figure(figsize=(10,6))
sns.countplot(y=data["numPrevOwners"],palette="mako")
# Out:
# <AxesSubplot:xlabel='count', ylabel='numPrevOwners'>

# %%
sns.jointplot(x=data["numPrevOwners"],y=data["price"],palette="mako")

# %%
plt.figure(figsize=(15,8))
sns.countplot(y = data["hasGuestRoom"])
# Out:
# <AxesSubplot:xlabel='count', ylabel='hasGuestRoom'>

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.lineplot(x="hasGuestRoom",y="price",data=data)
plt.subplot(2,2,2)
sns.barplot(x="hasGuestRoom",y="price",data=data,palette="viridis")
sns.lineplot(x="hasGuestRoom",y="price",data=data)
# Out:
# <AxesSubplot:xlabel='hasGuestRoom', ylabel='price'>

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x=data["floors"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
sns.jointplot(y="hasStormProtector",x="made",data=data,color="purple")

# %%
plt.figure(figsize=(50,8))
plt.subplot(2,2,1)
sns.barplot(y="hasStormProtector",x="made",data=data)
plt.figure(figsize=(40,8))
plt.subplot(2,2,2)
sns.lineplot(x=data["made"],y=data["hasStormProtector"])
# Out:
# <AxesSubplot:xlabel='made', ylabel='hasStormProtector'>

# %%
plt.figure(figsize=(12,10))
sns.violinplot(data=data,x=data["numPrevOwners"],y=data["made"])
# Out:
# <AxesSubplot:xlabel='numPrevOwners', ylabel='made'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data["numPrevOwners"],hue=data["isNewBuilt"])
# Out:
# <AxesSubplot:xlabel='numPrevOwners', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.jointplot(x="hasStorageRoom",y="basement",data=data,color="orange")

# %%
plt.figure(figsize=(30,6))
sns.lineplot(x=data["numberOfRooms"],y=data["hasGuestRoom"])
# Out:
# <AxesSubplot:xlabel='numberOfRooms', ylabel='hasGuestRoom'>

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.lineplot(x=data["hasGuestRoom"],y=data["squareMeters"])
plt.subplot(2,2,2)
sns.lineplot(x=data["hasGuestRoom"],y=data["squareMeters"])
sns.barplot(x=data["hasGuestRoom"],y=data["squareMeters"],palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='hasGuestRoom', ylabel='squareMeters'>

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.countplot(x=data["cityPartRange"],hue=data["hasYard"],palette="mako")
plt.subplot(2,2,3)
sns.barplot(x=data["cityPartRange"],y=data["floors"],palette="viridis",hue=data["hasYard"])
# Out:
# <AxesSubplot:xlabel='cityPartRange', ylabel='floors'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=data["cityPartRange"],hue=data["hasPool"])
# Out:
# <AxesSubplot:xlabel='cityPartRange', ylabel='count'>

# %%
plt.figure(figsize=(30,10))
plt.subplot(2,2,1)
sns.lineplot(x=data["cityPartRange"],y=data["numberOfRooms"])
plt.subplot(2,2,3)
sns.barplot(x=data["cityPartRange"],y=data["numberOfRooms"])
# Out:
# <AxesSubplot:xlabel='cityPartRange', ylabel='numberOfRooms'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=data["hasStormProtector"],hue=data["cityPartRange"])
# Out:
# <AxesSubplot:xlabel='hasStormProtector', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x=data["cityPartRange"],y=data["hasStormProtector"])
# Out:
# <AxesSubplot:xlabel='cityPartRange', ylabel='hasStormProtector'>

# %%
plt.figure(figsize=(30,8))
sns.countplot(x=data["numPrevOwners"],hue=data["cityPartRange"])
# Out:
# <AxesSubplot:xlabel='numPrevOwners', ylabel='count'>

# %%
sns.displot(x=data["bas_at_gar"],hue=data["isNewBuilt"],kind="kde",palette="mako",rug=True)

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x=data["hasGuestRoom"],y=data["squareMeters"])
# Out:
# <AxesSubplot:xlabel='hasGuestRoom', ylabel='squareMeters'>

# %%
df = data.drop(["cityCode","basement","attic","garage"],axis=1)
df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityPartRange  \
# 0         75523              3        0        1      63              3
# 1         80771             39        1        1      98              8
# 2         55712             58        0        1      19              6
# 3         32316             47        0        0       6             10
# 4         70429             19        1        1      90              3
#
#    numPrevOwners  made  isNewBuilt  hasStormProtector  hasStorageRoom  \
# 0              8  2005           0                  1               0
# 1              6  2015           1                  0               1
# 2              8  2021           0                  0               1
# 3              4  2012           0                  1               0
# 4              7  1990           1                  0               1
#
#    hasGuestRoom      price  bas_at_gar
# 0             7  7559081.5       14274
# ...

# %%
sns.scatterplot(x=df["squareMeters"],y=df["price"])
# Out:
# <AxesSubplot:xlabel='squareMeters', ylabel='price'>
